# %% [markdown]
# <a href="https://colab.research.google.com/github/Ana-AlonsoCanizares/Practicas_Individuales/blob/main/LAB02_Pr1_RA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importación de librerías a utilizar
import mlxtend as ml
from mlxtend.frequent_patterns import association_rules, apriori
from mlxtend import frequent_patterns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from numpy.core.function_base import linspace
from math import floor
from math import ceil
from numpy.ma.core import size

# %%
# Lectura de la base de datos
filename = 'BlackFriday.csv'
data = pd.read_csv(filename, sep = ',')

# Revisión de los datos
print(data.dtypes)
data.head(10)
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
# 5  1000013  P00350442      M  46-50           1             C
# 6  1000013  P00155442      M  46-50           1             C
# 7  1000013   P0094542      M  46-50           1             C
# 8  1000015  P00161842      M  26-35           7             A
# 9  1000022  P00067942      M  18-25          15             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
# 5                          3               1                   2
# 6                          3               1                   1
# 7                          3               1                   2
# 8                          1               0                  10
# 9                         4+               0                   5
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0
# 5                 3.0                15.0
# 6                11.0                15.0
# 7                 4.0                 9.0
# 8                13.0                16.0
# 9                14.0                 NaN

# %%
# Rellenamos los valores na con 0, ya que no tiene categoría
data = data.fillna(0)

# Quitamos los duplicados
data = data.drop_duplicates()

# %%
df = data.groupby(['User_ID','Product_ID'])['Product_Category_1'].sum().apply(lambda x: x>0).unstack().fillna(False).reset_index().set_index('User_ID')

# %%
df.head(10)
# Out:
# Product_ID  P00000142  P00000242  P00000342  P00000442  P00000542  P00000642  \
# User_ID
# 1000001         False      False      False      False      False      False
# 1000002         False      False      False      False      False      False
# 1000003         False      False      False      False      False      False
# 1000004         False      False      False      False      False      False
# 1000005         False      False      False      False      False       True
# 1000006         False      False      False      False      False      False
# 1000007         False      False      False      False      False       True
# 1000008         False      False      False      False      False      False
# 1000009          True      False      False      False      False      False
# 1000010          True      False      False      False      False      False
#
# Product_ID  P00000742  P00000842  P00000942  P00001042  ...  P0099042  \
# User_ID                                                 ...
# 1000001         False      False      False      False  ...     False
# 1000002         False      False      False      False  ...     False
# 1000003         False      False      False      False  ...     False
# 1000004         False      False      False      False  ...     False
# 1000005         False      False      False      False  ...     False
# 1000006         False      False      False      False  ...     False
# 1000007         False      False      False      False  ...     False
# 1000008         False      False      False      False  ...     False
# 1000009         False      False      False      False  ...     False
# 1000010          True      False      False      False  ...     False
#
# Product_ID  P0099142  P0099242  P0099342  P0099442  P0099542  P0099642  \
# User_ID
# 1000001        False     False     False     False     False     False
# 1000002        False     False     False     False     False     False
# 1000003        False     False     False     False     False     False
# 1000004        False     False     False     False     False     False
# 1000005        False     False     False     False     False     False
# 1000006        False     False     False     False     False     False
# 1000007        False     False     False     False     False     False
# 1000008        False      True     False     False     False     False
# 1000009        False     False      True     False     False     False
# 1000010        False     False     False     False     False     False
#
# Product_ID  P0099742  P0099842  P0099942
# User_ID
# 1000001        False     False     False
# 1000002        False     False     False
# 1000003        False     False     False
# 1000004        False     False     False
# 1000005        False     False     False
# 1000006        False     False     False
# 1000007        False     False     False
# 1000008        False     False     False
# 1000009        False     False     False
# 1000010        False     False     False
#
# [10 rows x 3491 columns]

# %%
print(df.shape)
# Out:
# (5879, 30663)

# %%
# Building the model
frq_items = apriori(df, min_support = 0.05, use_colnames = True)
print(frq_items)

# Collecting the inferred rules in a dataframe
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
print(rules.head())
# Out:
#       support     itemsets
# 0    0.082159  (P00000142)
# 1    0.052792  (P00002142)
# 2    0.058903  (P00003242)
# 3    0.066033  (P00003442)
# 4    0.053641  (P00003942)
# ..        ...          ...
# 107  0.053132  (P00329542)
# 108  0.071465  (P00334242)
# 109  0.052792  (P00350942)
# 110  0.060771  (P00355142)
# 111  0.066542   (P0097242)
#
# [112 rows x 2 columns]
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []
